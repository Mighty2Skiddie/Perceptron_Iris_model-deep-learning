# %% [markdown]
# <a href="https://colab.research.google.com/github/Mighty2Skiddie/Perceptron_Iris_model-deep-learning/blob/main/Perceptron_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn.datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=sklearn.datasets.load_iris()

# %%
data=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
data['Class']=iris.target

# %%
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Class
# 0        0
# ...

# %%
data.loc[data['Class'] == 2]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %%
data.drop(data[data['Class'] == 2].index, inplace=True)

# %%
data
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# ..                ...               ...                ...               ...
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#     Class
# 0       0
# 1       0
# ...

# %%
data.drop('petal length (cm)',axis=1,inplace=True)

# %%
data.drop('petal width (cm)',axis=1,inplace=True)

# %%
data
# Out:
#     sepal length (cm)  sepal width (cm)  Class
# 0                 5.1               3.5      0
# 1                 4.9               3.0      0
# 2                 4.7               3.2      0
# 3                 4.6               3.1      0
# 4                 5.0               3.6      0
# ..                ...               ...    ...
# 95                5.7               3.0      1
# 96                5.7               2.9      1
# 97                6.2               2.9      1
# 98                5.1               2.5      1
# 99                5.7               2.8      1
#
# [100 rows x 3 columns]

# %%
X=data.drop('Class',axis=1)
Y=data['Class']

# %%
from sklearn.metrics import accuracy_score

# %%
class Perceptron:

  def __init__(self):
      self.w = None
      self.b = None

  def model(self, x):
      return 1 if (np.dot(self.w, x) >= self.b) else 0

  def predict(self, X):
      Y = []
      for x in X:
        result = self.model(x)
        Y.append(result)
      return np.array(Y)

  def fit(self, X, Y, epochs = 1):
      self.w = np.ones(X.shape[1])
      self.b = 0

      accuracy = {}

      for i in range(epochs):
          for x, y in zip(X, Y):
            y_pred = self.model(x)
            if y == 1 and y_pred == 0:
              self.w = self.w + x
              self.b = self.b + 1
            elif y == 0 and y_pred == 1:
              self.w = self.w - x
              self.b = self.b - 1
          accuracy[i] = accuracy_score(self.predict(X), Y)

      plt.plot(accuracy.values())
      plt.xlabel('Epochs')
      plt.ylabel('Accuracy')
      plt.show()

# %%
perceptron=Perceptron()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,stratify=Y, random_state=42)

# %%
X_train=X_train.values
X_test=X_test.values

# %%
perceptron.fit(X_train, Y_train,25)
